# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
y = np.random.rand(10)
x = np.arange(10)

# %%
left, bottom, width, height = 0.1, 0.1, 0.8, 0.8
fig1 = plt.figure()
ax1 = fig1.add_axes((left, bottom, width, height), axisbg="#e1e1e1")
ax1.plot(x,y)

# %%
ax2 = plt.axes()
ax2.plot(x,y)

# %%
plt.axes?

# %%
aaa = plt.axes()

# %%
ccc = plt.subplot(111)
ccc.plot(x,y)

# %%
fig5,ax5 = plt.subplots(2,3)
data1 = np.random.randn(200, 2) * np.array([3, 1])
data2 = np.random.randn(200, 2) * np.array([1, 3])
ax5[0,0].bar
ax5[0,0].scatter(data1[:,0], data1[:,1], color="green", marker="s", s=30, alpha=0.5)
ax5[0,0].scatter(data2[:,0], data2[:,1], color="blue", marker="o", s=30, alpha=0.5)

ax5[1,0].hist([data1[:,1], data2[:,1]], bins=15, color=["green", "blue"], alpha=0.5, orientation='horizontal');

# %%
fig, axes = plt.subplots(1, 2, figsize=(8, 3.5), sharey=True)

data1 = np.random.randn(200, 2) * np.array([3, 1])
#area1 = (np.random.randn(200) + 0.5) * 100

data2 = np.random.randn(200, 2) * np.array([1, 3])
#area2 = (np.random.randn(200) + 0.5) * 100
axes[0].bar
axes[0].scatter(data1[:,0], data1[:,1], color="green", marker="s", s=30, alpha=0.5)
axes[0].scatter(data2[:,0], data2[:,1], color="blue", marker="o", s=30, alpha=0.5)

axes[1].hist([data1[:,1], data2[:,1]], bins=15, color=["green", "blue"], alpha=0.5, orientation='horizontal');

# %%
ax = plt.subplot(111)
ax.bar(x,y)
ax.plot(np.arange(10))
ax.plot(np.sin(np.linspace(1,5,num=10)))

# %%
np.linspace?

# %%
np.sin(np.linspace(1,5,num=10))
# Out:
# array([ 0.84147098,  0.99202822,  0.94983371,  0.72308588,  0.35584199,
#        -0.08054223, -0.50127705, -0.8246134 , -0.98772683, -0.95892427])

# %%
import matplotlib as mpl
mpl.style.library
# Out:
# {u'bmh': RcParams({u'axes.edgecolor': u'#bcbcbc',
#           u'axes.facecolor': u'#eeeeee',
#           u'axes.grid': True,
#           u'axes.labelsize': u'large',
#           u'axes.prop_cycle': cycler(u'color', [u'#348ABD', u'#A60628', u'#7A68A6', u'#467821', u'#D55E00', u'#CC79A7', u'#56B4E9', u'#009E73', u'#F0E442', u'#0072B2']),
#           u'axes.titlesize': u'x-large',
#           u'legend.fancybox': True,
#           u'lines.linewidth': 2.0,
#           u'mathtext.fontset': u'cm',
#           u'patch.antialiased': True,
#           u'patch.edgecolor': u'#eeeeee',
#           u'patch.facecolor': u'blue',
#           u'patch.linewidth': 0.5,
#           u'text.hinting_factor': 8}),
#  u'classic': RcParams({u'agg.path.chunksize': 0,
#           u'animation.avconv_args': [],
#           u'animation.avconv_path': u'avconv',
#           u'animation.bitrate': -1,
#           u'animation.codec': u'mpeg4',
#           u'animation.convert_args': [],
# ...

# %%
mpl.style.available
# Out:
# [u'seaborn-darkgrid',
#  u'seaborn-notebook',
#  u'classic',
#  u'seaborn-ticks',
#  u'grayscale',
#  u'bmh',
#  u'seaborn-talk',
#  u'dark_background',
#  u'ggplot',
#  u'fivethirtyeight',
#  u'seaborn-colorblind',
#  u'seaborn-deep',
#  u'seaborn-whitegrid',
#  u'seaborn-bright',
#  u'seaborn-poster',
#  u'seaborn-muted',
#  u'seaborn-paper',
#  u'seaborn-white',
#  u'seaborn-pastel',
#  u'seaborn-dark',
#  u'seaborn-dark-palette']

# %%
mpl.style.use('ggplot')

# %%
ax = plt.subplot(111)
ax.bar(x,y)
ax.plot(np.arange(10))
ax.plot(np.sin(np.linspace(1,5,num=10)))
ax.set_xlabel("$x$", fontsize=18)
ax.set_ylabel("$y$", fontsize=18)

# %%
a = plt.axes()
a.plot(x,y)
a.plot(x,np.zeros_like(x)+0.5,lw = 1,ls = '--' , color = 'green')
a.plot([0,9],[0.4,0.4],ls='--',lw = 1,color = 'red')

# %%
b = plt.axes()
b.plot(x,y)
b.plot(x,np.zeros_like(x)+0.5,lw = 10,ls = "--" , color = 'green')
b.plot([2 , 0], [2 , 0.8],lw = 10,ls = '--',color= 'red')
b.plot([0 , 0], [0 , 2], lw=10, ls='-.', color="yellow")
b.plot([1 , 1], [0 , 1], lw=5, ls='--', color="green")
b.plot([3,4],[1,1],marker = '1',lw = 0.5 , color = 'blue')
b.plot([4],[1],marker = ',',lw = 10 , color = 'blue')

# %%
b.plot?

# %%
ax.legend?

# %%
fff = plt.figure(figsize=(4,2))
aaaaa = fff.add_axes((0,0,1,1), axisbg="#e1e1e1")
bbb = fff.add_axes((1,1,2,2),axisbg="#e1e1e1")
ccc = fff.add_axes((0.5,0.5,0.5,0.5),axisbg="#e1e1e1")
aaaaa.plot(x,y);
# plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation


def data_gen(t=0):
    cnt = 0
    while cnt < 1000:
        cnt += 1
        t += 0.1
        yield t, np.sin(2*np.pi*t) * np.exp(-t/10.)


def init():
    ax.set_ylim(-1.1, 1.1)
    ax.set_xlim(0, 10)
    del xdata[:]
    del ydata[:]
    line.set_data(xdata, ydata)
    return line,

fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.grid()
xdata, ydata = [], []


def run(data):
    # update the data
    t, y = data
    xdata.append(t)
    ydata.append(y)
    xmin, xmax = ax.get_xlim()

    if t >= xmax:
        ax.set_xlim(xmin, 2*xmax)
        ax.figure.canvas.draw()
    line.set_data(xdata, ydata)

    return line,

ani = animation.FuncAnimation(fig, run, data_gen, blit=False, interval=10,
                              repeat=False, init_func=init)
plt.show()

# %%
ax.grid?
plt.axis('off')  # clear x- and y-axes
ax.arrow

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(-1, 2, .01)
s = np.sin(2*np.pi*t)

plt.plot(t, s)
# draw a thick red hline at y=0 that spans the xrange
l = plt.axhline(linewidth=4, color='r')

# draw a default hline at y=1 that spans the xrange
l = plt.axhline(y=1)

# draw a default vline at x=1 that spans the yrange
l = plt.axvline(x=1)

# draw a thick blue vline at x=0 that spans the upper quadrant of
# the yrange
l = plt.axvline(x=0, ymin=0.75, linewidth=4, color='b')

# draw a default hline at y=.5 that spans the middle half of
# the axes
l = plt.axhline(y=.5, xmin=0.25, xmax=0.75)

p = plt.axhspan(0.25, 0.75, facecolor='0.5', alpha=0.5)

p = plt.axvspan(1.25, 1.55, facecolor='g', alpha=0.5)

plt.axis([-1, 2, -1, 2])


plt.show()

# %%
fig = plt.figure()
plt.axis([0, 10, 0, 10])
t = "This is a really long string that I'd rather have wrapped so that it"\
    " doesn't go outside of the figure, but if it's long enough it will go"\
    " off the top or bottom!"
plt.text(4, 1, t, ha='left', rotation=15, wrap=True)
plt.text(6, 5, t, ha='left', rotation=15, wrap=True)
plt.text(5, 5, t, ha='right', rotation=-15, wrap=True)
plt.text(5, 10, t, fontsize=18, style='oblique', ha='center',
        va='top', wrap=True)
plt.text(3, 4, t, family='serif', style='italic', ha='right', wrap=True)
plt.text(-1, 0, t, ha='left', rotation=-15, wrap=True)

plt.show()
